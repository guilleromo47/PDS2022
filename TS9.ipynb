# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  2 21:30:58 2022

@author: Guilleromo
"""

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# import scipy.signal as sig
import scipy.io as sio 
from scipy import signal

# N=1000
fs=1000
block=
mat_struct = sio.loadmat('ECG_TP4.mat')
ecg_one_lead = mat_struct['ecg_lead']

plt.figure(1)
plt.plot(ecg_one_lead)

ECG= ecg_one_lead[0:1000000]
# Bartlett = sig.windows.bartlett(N).reshape((N,1))#aplico reshape, para no tener dim 0 en Bartlett 
# ecg=ecg_one_lead.reshape((N,1))
# ECG_Bartlett = Bartlett * ecg_one_lead
# sio.welch(ecg_one_lead, fs=1.0, window='hann', nperseg=1024, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
[f_med, Pxx_den_med ]= signal.welch(ECG, fs=fs, nperseg=block, average='median',axis=0)
plt.figure(2)
plt.plot(f_med,10*np.log10(2*np.abs(Pxx_den_med)))
# plt.plot(ECG_Bartlett)



# potencia de la ecg en tiempo
